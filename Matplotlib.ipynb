# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# 🎯 Sample 2D data
data = {
    'X': [1, 2, 1, 5, 6, 7, 8, 8, 25, 24, 23, 22],
    'Y': [2, 1, 3, 5, 5, 6, 6, 5, 25, 24, 23, 22]
}
df = pd.DataFrame(data)

# 🧠 Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(df)

# 📌 Assign clusters to the data
df['Cluster'] = kmeans.labels_

# 🎨 Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['X'], df['Y'], c=df['Cluster'], cmap='viridis', s=100)
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
            c='red', marker='X', s=200, label='Centroids')
plt.title("K-Means Clustering Example")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data (replace with your actual data)
year = [2015, 2016, 2017, 2018, 2019, 2020]
snown = [120, 95, 100, 85, 140, 110]  # snowfall in mm or cm

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(year, snown, marker='o', linestyle='-', color='blue', label='Snowfall')
plt.title("Yearly Snowfall")
plt.xlabel("Year")
plt.ylabel("Snowfall (mm)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
year = [2015, 2016, 2017, 2018, 2019, 2020]
snown = [120, 95, 100, 85, 140, 110]  # snowfall in mm or cm
plt.plot(year,snown,"go-")
plt.title("Line Graph of Yearly Sown Acerage")
plt.xlabel("Year")
plt.ylabel("Snow")
plt.legend()
plt.show()
# Out:
# /var/folders/l5/5w4j92t51pjdxlrcxdnhqzqm0000gn/T/ipykernel_3732/2338146267.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
